# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Global_Cybersecurity_Threats_2015-2024.csv")
df.head(20)
# Out:
#       Country  Year        Attack Type     Target Industry  \
# 0       China  2019           Phishing           Education
# 1       China  2019         Ransomware              Retail
# 2       India  2017  Man-in-the-Middle                  IT
# 3          UK  2024         Ransomware  Telecommunications
# 4     Germany  2018  Man-in-the-Middle                  IT
# 5     Germany  2017  Man-in-the-Middle              Retail
# 6     Germany  2016               DDoS  Telecommunications
# 7      France  2018      SQL Injection          Government
# 8       India  2016  Man-in-the-Middle             Banking
# 9          UK  2023               DDoS          Healthcare
# 10      China  2019           Phishing  Telecommunications
# 11      China  2016      SQL Injection          Healthcare
# 12      India  2019         Ransomware           Education
# 13     France  2023               DDoS          Healthcare
# 14     France  2024               DDoS                  IT
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Attack Type', 'Target Industry',
#        'Financial Loss (in Million $)', 'Number of Affected Users',
#        'Attack Source', 'Security Vulnerability Type',
#        'Defense Mechanism Used', 'Incident Resolution Time (in Hours)'],
#       dtype='object')

# %%
df['Country'].unique()
# Out:
# array(['China', 'India', 'UK', 'Germany', 'France', 'Australia', 'Russia',
#        'Brazil', 'Japan', 'USA'], dtype=object)

# %%
counts = df['Country'].value_counts()
counts.index = ['China', 'India', 'UK', 'Germany', 'France', 'Australia', 'Russia',
       'Brazil', 'Japan', 'USA']

plt.bar(counts.index, counts.values)
plt.ylabel("Number of Incidents")
plt.title("Cyber Incidents in each country")
# Out:
# Text(0.5, 1.0, 'Cyber Incidents in each country')

# %%
import pandas as pd

data = {
    'English-speaking': [eng_15_19, eng_20_24],
    'Non-English-speaking': [non_eng_15_19, non_eng_20_24]
}

index = ['2015–2019', '2020–2024']

summary_df = pd.DataFrame(data, index=index)

summary_df.plot(kind='bar')
plt.ylabel("Number of Incidents")
plt.title("Global Cyber Threats by Language Group and Period")
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, '2015–2019'), Text(1, 0, '2020–2024')])
